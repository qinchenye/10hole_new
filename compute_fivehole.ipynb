# %%
# %pylab inline

import math
import numpy as np
from scipy.sparse.linalg import inv
#from numpy.linalg import inv
import scipy.sparse as sps
import scipy.sparse.linalg
from scipy import integrate
import sys
import matplotlib.pyplot as plt
sys.path.append('../../src/')
from pylab import *

import parameters as pam
import lattice as lat
import variational_space as vs

#import hamiltonian as ham
import hamiltonian_d10U_2 as ham   # convention of putting U/2 to d8 and d10 separately

import basis_change as basis
import get_state as getstate
import utility as util
import plotfig as fig
import ground_state_eigsh as gs
#import ground_state_lanczos as gs
import lanczos
import time
start_time = time.time()
M_PI = math.pi
                  
#####################################
def compute_Aw_main(A,ep,epbilayer,tpd,tpp,tpzd,tz_a1a1,tz_b1b1,pds,pdp,pps,ppp,Upp,\
                    d_000_double,d_200_double,d_002_double,d_202_double, p_double, double_000_part, idx_000, hole345_000_part,\
                    double_200_part, idx_200, hole345_200_part,double_002_part, idx_002, hole345_002_part,\
                    double_202_part, idx_202, hole345_202_part,\
                    U_000,S_000_val, Sz_000_val,U_200,S_200_val, Sz_200_val, U_002,S_002_val, Sz_002_val,U_202,S_202_val, Sz_202_val,\
                    AorB_000_sym, AorB_200_sym,AorB_002_sym, AorB_202_sym): 
    if Norb==8:
        fname = 'ep'+str(ep)+'_epbilayer'+str(pam.epbilayer)+'_tpd'+str(tpd)+'_tpp'+str(tpp) \
                  +'_tpzd'+str(tpzd)+'_tz_a1a1'+str(tz_a1a1)+'_Mc'+str(Mc)+'_Norb'+str(Norb)+'_eta'+str(eta)
        flowpeak = 'Norb'+str(Norb)+'_tpp'+str(tpp)+'_Mc'+str(Mc)+'_eta'+str(eta)
    elif Norb==10 or Norb==11 or Norb==12:
        fname = 'ep'+str(ep)+'_epbilayer'+str(pam.epbilayer)+'_pdp'+str(pdp)+'_pps'+str(pps)+'_ppp'+str(ppp) \
                  +'_tz_a1a1'+str(tz_a1a1)+'_tpzd'+str(tpzd)+'_Mc'+str(Mc)+'_Norb'+str(Norb)+'_eta'+str(eta)
        flowpeak = 'Norb'+str(Norb)+'_pps'+str(pps)+'_ppp'+str(ppp)+'_Mc'+str(Mc)+'_eta'+str(eta)
                
    w_vals = np.arange(pam.wmin, pam.wmax, pam.eta)
    Aw = np.zeros(len(w_vals))
    Aw_dd_total = np.zeros(len(w_vals))
    Aw_d8_total = np.zeros(len(w_vals))

    # set up H0
    if Norb==8 or Norb==5:
        tpd_nn_hop_dir, tpd_orbs, tpd_nn_hop_fac, tpp_nn_hop_fac \
                                   = ham.set_tpd_tpp(Norb,tpd,tpp,0,0,0,0)
    elif Norb==10 or Norb==12:
        tpd_nn_hop_dir, tpd_orbs, tpd_nn_hop_fac, tpp_nn_hop_fac \
                                   = ham.set_tpd_tpp(Norb,0,0,pds,pdp,pps,ppp)
        
    if Norb==5:  
        tapzd_nn_hop_dir, tapzd_orbs, tapzd_nn_hop_fac\
                                   = ham.set_tapzd(Norb,tapzd)        
        
    
    tz_fac = ham.set_tz(Norb,if_tz_exist,tz_a1a1,tz_b1b1)
            
    T_pd   = ham.create_tpd_nn_matrix(VS,tpd_nn_hop_dir, tpd_orbs, tpd_nn_hop_fac)
    T_pp   = ham.create_tpp_nn_matrix(VS,tpp_nn_hop_fac)  
#     T_z    = ham.create_tz_matrix(VS,tz_fac)
#     T_apzd   = ham.create_tapzd_nn_matrix(VS,tapzd_nn_hop_dir, tapzd_orbs, tapzd_nn_hop_fac)
    Esite  = ham.create_edep_diag_matrix(VS,A,ep,epbilayer)      
    
    H0 = T_pd + T_pp  + Esite    
#     H0 = T_pd   
    print("H0 %s seconds ---" % (time.time() - start_time))  
    
    '''
    Below probably not necessary to do the rotation by multiplying U and U_d
    the basis_change.py is only for label the state as singlet or triplet
    and assign the interaction matrix
    '''
    if pam.if_H0_rotate_byU==1:
        H0_000_new = U_000_d.dot(H0.dot(U_000))  
    
    clf()

    if Norb==5 or Norb==8 or Norb==10 or Norb==11 or Norb==12:     
        Hint_000 = ham.create_interaction_matrix_ALL_syms(VS,d_000_double,p_double,double_000_part, idx_000, hole345_000_part,\
                                                      S_000_val, Sz_000_val,AorB_000_sym, A, Upp)
        Hint_200 = ham.create_interaction_matrix_ALL_syms(VS,d_200_double,p_double,double_200_part, idx_200, hole345_200_part,\
                                                      S_200_val, Sz_200_val,AorB_200_sym, A, Upp)    
        Hint_002 = ham.create_interaction_matrix_ALL_syms(VS,d_002_double,p_double,double_002_part, idx_002, hole345_002_part,\
                                                      S_002_val, Sz_002_val,AorB_002_sym, A, Upp)
        Hint_202 = ham.create_interaction_matrix_ALL_syms(VS,d_202_double,p_double,double_202_part, idx_202, hole345_202_part,\
                                                      S_202_val, Sz_202_val,AorB_202_sym, A, Upp)          
        if pam.if_H0_rotate_byU==1:
            H_000 = H0_000_new + Hint_000
            
            # continue rotate the basis for setting Cu layer's interaction (d_Cu_double)
            H0_200_new = U_200_d.dot(H_000.dot(U_200)) 
            H_200 = H0_200_new + Hint_200
            H0_002_new = U_002_d.dot(H_200.dot(U_002))
            H_002 = H0_002_new + Hint_002
            H0_202_new = U_202_d.dot(H_002.dot(U_202))
            H = H0_202_new + Hint_202           
            
        else:
            H = H0 + Hint_200 + Hint_000+ Hint_202 + Hint_002
        H.tocsr()

        ####################################################################################
        # compute GS only for turning on full interactions
        if pam.if_get_ground_state==1:
            vals = gs.get_ground_state(H, VS, S_000_val,Sz_000_val,S_200_val,Sz_200_val,S_002_val,Sz_002_val,S_202_val,Sz_202_val)
#             if Norb==8:
#                 util.write_GS('Egs_'+flowpeak+'.txt',A,ep,tpd,vals[0])
#                 #util.write_GS_components('GS_weights_'+flowpeak+'.txt',A,ep,tpd,wgt_d8, wgt_d9L, wgt_d10L2)
#             elif Norb==10 or Norb==11 or Norb==12:
#                 util.write_GS2('Egs_'+flowpeak+'.txt',A,ep,pds,pdp,vals[0])
#                 #util.write_GS_components2('GS_weights_'+flowpeak+'.txt',A,ep,pds,pdp,wgt_d8, wgt_d9L, wgt_d10L2)
            
        #########################################################################
        '''
        Compute A(w) for various states
        '''
#         if pam.if_compute_Aw==1:
#             # compute d8
#             fig.compute_Aw_d8_sym(H, VS, d_double_no_eh, S_val, Sz_val, AorB_sym, A, w_vals, "Aw_d8_sym_", fname)

#             # compute d9L
#             b1L_state_indices, a1L_state_indices, b1L_state_labels, a1L_state_labels \
#                     = getstate.get_d9L_state_indices(VS, S_val, Sz_val)
#             fig.compute_Aw1(H, VS, w_vals, b1L_state_indices, b1L_state_labels, "Aw_b1L_", fname)
#             fig.compute_Aw1(H, VS, w_vals, a1L_state_indices, a1L_state_labels, "Aw_a1L_", fname)

#             # compute d10L2
#             d10L2_state_indices, d10L2_state_labels = getstate.get_d10L2_state_indices(VS, S_val, Sz_val)
#             fig.compute_Aw1(H, VS, w_vals, d10L2_state_indices, d10L2_state_labels, "Aw_d10L2_", fname)

#             # compute d8Ls for some special states
#             a1b1Ls_S0_state_indices, a1b1Ls_S0_state_labels, \
#             a1b1Ls_S1_state_indices, a1b1Ls_S1_state_labels, \
#             a1a1Ls_state_indices, a1a1Ls_state_labels \
#                                             = getstate.get_d8Ls_state_indices(VS, d_double_one_eh, S_val, Sz_val)
#             fig.compute_Aw1(H, VS, w_vals, a1b1Ls_S0_state_indices, a1b1Ls_S0_state_labels, "Aw_a1b1Ls_S0_", fname)
#             fig.compute_Aw1(H, VS, w_vals, a1b1Ls_S1_state_indices, a1b1Ls_S1_state_labels, "Aw_a1b1Ls_S1_", fname)
#             fig.compute_Aw1(H, VS, w_vals, a1a1Ls_state_indices, a1a1Ls_state_labels, "Aw_a1a1Ls_", fname)

#             # compute d9L2s
#             d9L2s_state_indices, d9L2s_state_labels = getstate.get_d9L2s_state_indices(VS)
#             fig.compute_Aw1(H, VS, w_vals, d9L2s_state_indices, d9L2s_state_labels, "Aw_d9L2s_", fname)
        
    
##########################################################################
if __name__ == '__main__': 
    Mc  = pam.Mc
    print ('Mc=',Mc)

    Norb = pam.Norb
    eta  = pam.eta
    ed   = pam.ed
    epbilayer   = pam.epbilayer

    As = pam.As
    B  = pam.B
    C  = pam.C

    tz_a1a1 = pam.tz_a1a1
    tz_b1b1 = pam.tz_b1b1    
    
    if_tz_exist  = pam.if_tz_exist      
    
        # set up VS
    VS = vs.VariationalSpace(Mc)
    
    d_000_double, idx_000, hole345_000_part,  double_000_part, \
    d_200_double, idx_200, hole345_200_part,  double_200_part, \
    d_002_double, idx_002, hole345_002_part,  double_002_part, \
    d_202_double, idx_202, hole345_202_part,  double_202_part, \
    p_double = ham.get_double_occu_list(VS)
    
    
    # change the basis for d_double states to be singlet/triplet

    if pam.basis_change_type=='d_double':
        U_000,S_000_val, Sz_000_val, AorB_000_sym,\
                                        =  basis.create_singlet_triplet_basis_change_matrix_d_double\
                                        (VS, d_000_double,double_000_part, idx_000, hole345_000_part)
        U_200,S_200_val, Sz_200_val, AorB_200_sym,\
                                        =  basis.create_singlet_triplet_basis_change_matrix_d_double\
                                        (VS, d_200_double,double_200_part, idx_200, hole345_200_part)
        U_002,S_002_val, Sz_002_val, AorB_002_sym,\
                                        =  basis.create_singlet_triplet_basis_change_matrix_d_double\
                                        (VS, d_002_double,double_002_part, idx_002, hole345_002_part)
        U_202,S_202_val, Sz_202_val, AorB_202_sym,\
                                        =  basis.create_singlet_triplet_basis_change_matrix_d_double\
                                        (VS, d_202_double,double_202_part, idx_202, hole345_202_part)
        
        

    U_000_d = (U_000.conjugate()).transpose()
    U_200_d = (U_200.conjugate()).transpose()   
    U_002_d = (U_002.conjugate()).transpose()
    U_202_d = (U_202.conjugate()).transpose()       
    
    # check if U if unitary
    #checkU_unitary(U,U_d)
    
    if Norb==8 or Norb==5:
        for tpd in pam.tpds:
            for tapzd in pam.tapzds:                            
                for ep in pam.eps:               
                    for A in pam.As:
                        util.get_atomic_d8_energy(A,B,C)
                        for tpp in pam.tpps:
                            for Upp in pam.Upps:

                                print ('===================================================')
                                print ('A=',A, 'epbilayer=', epbilayer, 'ep=', ep, ' tpd=',tpd,' tpp=',tpp,\
                                      ' Upp=',Upp,'tz_a1a1=',tz_a1a1,'tapzd=',tapzd)
                                compute_Aw_main(A,ep,epbilayer,tpd,tpp,tapzd,tz_a1a1,tz_b1b1,0,0,0,0,Upp,\
                                d_000_double, d_200_double,d_002_double, d_202_double, p_double, double_000_part, idx_000, hole345_000_part,\
                                    double_200_part, idx_200, hole345_200_part, \
                                    double_002_part, idx_002, hole345_002_part, double_202_part, idx_202, hole345_202_part,\
                            U_000,S_000_val, Sz_000_val,U_200,S_200_val, Sz_200_val,U_002,S_002_val, Sz_002_val,U_202,S_202_val, Sz_202_val,\
                                                AorB_000_sym, AorB_200_sym,AorB_002_sym, AorB_202_sym)

                        
    print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# Ni_orbs =  ['d3z2r2', 'dx2y2']
# O1_orbs =  ['px']
# O2_orbs =  ['py']
# Obilayer_orbs =  ['apz']
# compute A(w) for symmetries =  ['1A1', '3B1', '3B1', '1A2', '3A2', '1E', '3E']
# Mc= 4
# VS.dim =  66048
# len(d_000_list) 66048
# len(d_200_list) 66048
# len(p_list) 0
# len(apz_list) 0
# len(idx_000) 66048
# len(idx_200) 66048
# len(d_002_list) 70144
# len(d_202_list) 69120
# len(idx_002) 70144
# len(idx_202) 69120
# basis 22.695833206176758 seconds ---
# basis 22.361321210861206 seconds ---
# basis 24.178744077682495 seconds ---
# basis 22.452192783355713 seconds ---
# E_1S =  12.16
# E_1G =  7.76
# E_1D =  6.71
# E_3P =  7.05
# E_3F =  4.8
# ===================================================
# A= 6.0 epbilayer= 2.42 ep= 3.23  tpd= 1.58  tpp= 0.35  Upp= 0 tz_a1a1= 0.044 tapzd= 1.66
# start create_tpd_nn_matrix
# ==========================
# start create_tpp_nn_matrix
# ==========================
# start create_edep_diag_matrix
# =============================
# H0 114.17854499816895 seconds ---
# start create_interaction_matrix_ALL_syms (four holes)
# ======================================================
# ---create_interaction_matrix_ALL_syms 8.887836933135986 seconds ---
# start create_interaction_matrix_ALL_syms (four holes)
# ======================================================
# ---create_interaction_matrix_ALL_syms 8.703563213348389 seconds ---
# start create_interaction_matrix_ALL_syms (four holes)
# ======================================================
# ---create_interaction_matrix_ALL_syms 8.88974905014038 seconds ---
# start create_interaction_matrix_ALL_syms (four holes)
# ======================================================
# ---create_interaction_matrix_ALL_syms 8.54690146446228 seconds ---
# start getting ground state
# lowest eigenvalue of H from np.linalg.eigsh =
# [22.37574071 22.37574071 22.37574071 22.37574071 22.37574071 22.37574071
#  22.37574071 22.37574071 22.37574071 22.37574071]
# 22.37574070906497
# Degeneracy of ground state is  4
# eigenvalue =  22.37574070906497
# Compute the weights in GS (lowest Aw peak)
# 0   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.04111069053718014
#
# 1   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.03412004902500394
#
# 2   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.03412004902500384
#
# 3   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.031700037624737595
#
# 4   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.024339626511151978
#
# 5   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.021067554272217955
#
# 6   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.021067554272217914
#
# 7   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.020609206697250883
#
# 8   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.018305467527113147
#
# 9   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.018305467527113147
#
# 10   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.018156133243898948
#
# 11   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.017146401368942625
#
# 12   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.017146401368942604
#
# 13   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.017146401368942583
#
# 14   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.017146401368942563
#
# 15   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.017001668697362846
#
# 16   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.017001668697362807
#
# 17   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.016849485826233534
#
# 18   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.01592649797922446
#
# 19   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.01592649797922444
#
# 20   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.015822950175491738
#
# 21   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.015068784987357193
#
# 22   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.015068784987357186
#
# 23   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.014000010688972258
#
# 24   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.010749357314825665
#
# 25   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.009304278704430338
#
# 26   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.009304278704430298
#
# 27   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.009183770892400722
#
# 28   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.009101853993623784
#
# 29   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.008084430185226022
#
# 30   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.008084430185226013
#
# 31   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.007622122347950838
#
# 32   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.007622122347950821
#
# 33   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.007572539985103814
#
# 34   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0075725399851038116
#
# 35   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.007572539985103807
#
# 36   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.00757253998510379
#
# 37   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.007508620220302637
#
# 38   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.007508620220302627
#
# 39   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.007441410147945186
#
# 40   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.007081512838196355
#
# 41   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.007033781618386733
#
# 42   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.007033781618386733
#
# 43   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.006988050746510752
#
# 44   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.005437260979182415
#
# 45   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.004706308484996057
#
# 46   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.00470630848499605
#
# 47   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0046039176211491875
#
# 48   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.004089282316853292
#
# 49   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.004089282316853278
#
# 50   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.003830357012834817
#
# 51   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0038303570128348082
#
# 52   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0038303570128348082
#
# 53   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0038303570128348043
#
# 54   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.003798024992159102
#
# 55   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.003798024992159101
#
# 56   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.003764028661668342
#
# 57   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0035578412001430844
#
# 58   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.00355784120014308
#
# 59   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.00353470952092599
#
# 60   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.003352490712842272
#
# 61   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   dx2y2 up 0 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.002841070107945684
#
# 62   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 2 0 2   px up 3 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.002795563235526598
#
# 63   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.002782418538423581
#
# 64   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0027824185384235766
#
# 65   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py up 2 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.002721327117848734
#
# 66   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py up 2 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0027213271178487277
#
# 67   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 2 0 2   py up 2 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0026583715219650837
#
# 68   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 2 0 2   py up 2 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0026583715219650693
#
# 69   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.00259398196598462
#
# 70   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0025850716771000817
#
# 71   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   dx2y2 up 0 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0024835642552045287
#
# 72   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.002375495299115367
#
# 73   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   dx2y2 up 0 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.002357962128584087
#
# 74   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   dx2y2 up 0 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0023579621285840834
#
# 75   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   dx2y2 up 0 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0021907204218557757
#
# 76   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0021528899342944012
#
# 77   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0021528899342943986
#
# 78   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.00208313654489419
#
# 79   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   dx2y2 up 0 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.002061248133687028
#
# 80   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   dx2y2 up 0 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.002061248133687002
#
# 81   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0020001932549697436
#
# 82   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0019848455661161126
#
# 83   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001971555695256106
#
# 84   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0019715556952561034
#
# 85   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   dx2y2 up 0 0 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.00191505127509913
#
# 86   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0018317203962127711
#
# 87   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0017289109014917297
#
# 88   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0017289109014917224
#
# 89   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px up 3 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0017227296232101247
#
# 90   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0017180149279179837
#
# 91   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0017180149279179832
#
# 92   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up 1 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0016820584722815944
#
# 93   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0016806376431232738
#
# 94   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0016062855181399592
#
# 95   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0015357696843267994
#
# 96   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0014927725386510873
#
# 97   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0014927725386510778
#
# 98   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up 1 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0014703967653729344
#
# 99   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 -1 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0014559327004295796
#
# 100   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 1 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.001455932700429576
#
# 101   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up -1 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0014242572997670172
#
# 102   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0014064144290438967
#
# 103   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0013982531209509087
#
# 104   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.001398253120950908
#
# 105   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0013982531209509055
#
# 106   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.001398253120950905
#
# 107   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.00138645047470545
#
# 108   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0013864504747054475
#
# 109   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 2 1 2   px up 3 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013850118130662283
#
# 110   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 2 -1 2   px up 3 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013850118130662272
#
# 111   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0013740402802901147
#
# 112   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 2 -1 2   py up 2 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013342283637395745
#
# 113   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 2 1 2   py up 2 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013342283637395726
#
# 114   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 2 -1 2   py up 2 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013342283637395663
#
# 115   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 2 1 2   py up 2 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013342283637395639
#
# 116   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001329310092714514
#
# 117   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001329310092714511
#
# 118   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 3 0 2   px up 3 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013234387365084858
#
# 119   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013003895047100724
#
# 120   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0012987725544328773
#
# 121   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.001298772554432875
#
# 122   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0012903284479045048
#
# 123   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0012889822579666096
#
# 124   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 1 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0012727255137621443
#
# 125   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 -1 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0012727255137621439
#
# 126   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up 1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0012650509131254698
#
# 127   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up 1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0012650509131254659
#
# 128   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up -1 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0012450359848642965
#
# 129   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 2 0 2   px dn 3 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0012346330828497184
#
# 130   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0012333231286545921
#
# 131   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0012173445759135356
#
# 132   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001217344575913534
#
# 133   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 2 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001201847429617777
#
# 134   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 2 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001201847429617775
#
# 135   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001190859919600149
#
# 136   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 -1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0011849503803419601
#
# 137   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0011849503803419586
#
# 138   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 -1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0011849503803419538
#
# 139   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0011849503803419519
#
# 140   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up -1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0011749482212564007
#
# 141   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up -1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0011749482212563978
#
# 142   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 2 0 2   py dn 2 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0011740437081917854
#
# 143   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 2 0 2   py dn 2 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0011740437081917846
#
# 144   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up 1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0011644311951383662
#
# 145   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0011550293129065218
#
# 146   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0011550293129065194
#
# 147   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 3 0 2   py up 2 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001147462125949375
#
# 148   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 3 0 2   py up 2 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0011474621259493713
#
# 149   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up 1 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0011058633224379445
#
# 150   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up 1 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0011058633224379354
#
# 151   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 -1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0011006455192504735
#
# 152   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0011006455192504707
#
# 153   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up -1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0010934895565048554
#
# 154   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010818951312035927
#
# 155   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010818951312035923
#
# 156   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010818951312035923
#
# 157   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010818951312035912
#
# 158   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010727628608607216
#
# 159   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010727628608607216
#
# 160   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010697980807305638
#
# 161   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010697980807305588
#
# 162   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0010675226234961083
#
# 163   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0010675226234961083
#
# 164   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010631605015210166
#
# 165   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010577431682749824
#
# 166   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010577431682749806
#
# 167   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0010442975068367998
#
# 168   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 -1 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0010358422344375075
#
# 169   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 1 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0010358422344375062
#
# 170   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 -1 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0010358422344374954
#
# 171   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 1 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0010358422344374932
#
# 172   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up -1 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.001027098696321255
#
# 173   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up -1 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0010270986963212402
#
# 174   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up 1 0 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0010179050794285368
#
# 175   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.001016373037188858
#
# 176   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001004922272031743
#
# 177   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010049222720317386
# eigenvalue =  22.375740709065628
# Compute the weights in GS (lowest Aw peak)
# 0   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.03203055887899275
#
# 1   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.02835070613824596
#
# 2   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.026583942642881695
#
# 3   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 1 0
# ...
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0017702413583118187
#
# 111   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0017317278306759748
#
# 112   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0016502032399009004
#
# 113   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0016502032399008976
#
# 114   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0015943664303778736
#
# 115   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0015943664303778719
#
# 116   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up 1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0015842162489957817
#
# 117   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up 1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0015842162489957806
#
# 118   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0015596792532370193
#
# 119   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0015381517608085836
#
# 120   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0015381517608085832
#
# 121   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0015331603056896216
#
# 122   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0014839067956199214
#
# 123   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0014839067956199203
#
# 124   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 -1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0014839067956199203
#
# 125   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 -1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0014839067956199203
#
# 126   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up -1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.00147138114721796
#
# 127   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up -1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.00147138114721796
#
# 128   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up 1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.001458210733684182
#
# 129   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0014407590201182586
#
# 130   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0014407590201182582
#
# 131   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0014407590201182575
#
# 132   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0014407590201182565
#
# 133   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.00142859758183175
#
# 134   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0014285975818317494
#
# 135   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0014158101263435927
#
# 136   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013853351243576463
#
# 137   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001385335124357638
#
# 138   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0013783322851990654
#
# 139   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   py up 0 -1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0013783322851990648
#
# 140   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up -1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0013693709127032042
#
# 141   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013565708046876033
#
# 142   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013382543152188435
#
# 143   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013382543152188427
#
# 144   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0013295535138650846
#
# 145   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px dn 1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0013186881720866825
#
# 146   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px up 3 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.001300956619059885
#
# 147   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0012976184321732015
#
# 148   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0012976184321732004
#
# 149   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001297618432173195
#
# 150   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0012976184321731924
#
# 151   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0012866652427348498
#
# 152   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0012866652427348468
#
# 153   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0012751482314162178
#
# 154   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0012052976536080597
#
# 155   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0012052976536080574
#
# 156   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   px up -1 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001197461283990718
#
# 157   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 dn 2 0 0   dx2y2 dn 2 0 0   px up 1 0 2   px dn 3 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= -1 , weight =  0.0011914668918736342
#
# 158   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   px up 1 0 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0011771768117109958
#
# 159   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.001125893575540297
#
# 160   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py up 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0011258935755402962
#
# 161   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py dn 0 -1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.001094452671370419
#
# 162   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   py dn 0 1 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0010944526713704186
#
# 163   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 dn 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px up -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 0 , weight =  0.0010460380253240556
#
# 164   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 2 -1 2   px up 3 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.001045921693925861
#
# 165   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 2 1 2   px up 3 0 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.001045921693925861
#
# 166   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 1 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0010189242779607853
#
# 167   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 dn 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 0 -1 2   px up 1 0 0
#  S_Ni= 1 ,  Sz_Ni= -1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0010189242779607844
#
# 168   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 dn 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   dx2y2 up 0 0 2   px dn -1 0 0
#  S_Ni= 1 ,  Sz_Ni= 0 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.001016827110521063
#
# 169   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 2 -1 2   py up 2 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.001007571471319704
#
# 170   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 2 1 2   py up 2 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0010075714713197036
#
# 171   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 2 1 2   py up 2 1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0010075714713197036
#
# 172   d3z2r2 dn 0 0 2   dx2y2 dn 0 0 2   d3z2r2 dn 2 0 2   dx2y2 dn 2 0 2   d3z2r2 up 0 0 0 dx2y2 up 0 0 0   d3z2r2 up 2 0 0   dx2y2 up 2 0 0   py up 2 -1 2   py up 2 -1 0
#  S_Ni= 1 ,  Sz_Ni= 1 ,  S_Cu= 1 ,  Sz_Cu= 1 , weight =  0.0010075714713197036
# sumweight= 1.0000000000001
# wgt_d8d8L_d8d8L= 0.6791429876031005
# --- get_ground_state 239.88432669639587 seconds ---
# --- 389.1618309020996 seconds ---
